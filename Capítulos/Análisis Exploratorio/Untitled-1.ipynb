# %%
import pandas as pd

df=pd.read_csv("./skim_poliformat.csv")

# %%
nombres=df.columns.to_list()

print(nombres)
# Out:
# ['Unnamed: 0', 'skim_type', 'skim_variable', 'n_missing', 'complete_rate', 'numeric.mean', 'numeric.sd', 'numeric.p0', 'numeric.p25', 'numeric.p50', 'numeric.p75', 'numeric.p100']

# %%
nombres_buenos=['skim_variable', 'n_missing', 'complete_rate','numeric.mean', 'numeric.sd', 'numeric.p0', 'numeric.p25', 'numeric.p50', 'numeric.p75', 'numeric.p100']

df_bueno=df[nombres_buenos]
nombres_buenos2=['Variable', 'NAs', 'Compleción','Media', 'SD', 'Mín', 'p25', 'p50', 'p75', 'Máx']
df_bueno.columns=nombres_buenos2

# %%
print(df_bueno.to_latex())
# Out:
# \begin{tabular}{llrrrrrrrrr}
# \toprule
#  & Variable & NAs & Compleción & Media & SD & Mín & p25 & p50 & p75 & Máx \\
# \midrule
# 0 & dni_hash & 0 & 1 & NaN & NaN & NaN & NaN & NaN & NaN & NaN \\
# 1 & asinom & 0 & 1 & NaN & NaN & NaN & NaN & NaN & NaN & NaN \\
# 2 & pft_events_2024_7 & 0 & 1 & 0.023311 & 0.542814 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 25.000000 \\
# 3 & pft_events_2024_8 & 0 & 1 & 0.248086 & 2.314463 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 82.000000 \\
# 4 & pft_events_2024_9 & 0 & 1 & 20.831982 & 35.657392 & 0.000000 & 0.000000 & 0.000000 & 30.250000 & 515.000000 \\
# 5 & pft_events_2024_10 & 0 & 1 & 40.967005 & 67.388241 & 0.000000 & 0.000000 & 0.000000 & 64.000000 & 1025.000000 \\
# 6 & pft_events_2024_11 & 0 & 1 & 21.878153 & 43.088288 & 0.000000 & 0.000000 & 0.000000 & 31.000000 & 551.000000 \\
# 7 & pft_events_2024_12 & 0 & 1 & 48.397297 & 81.615701 & 0.000000 & 0.000000 & 0.000000 & 76.000000 & 1269.000000 \\
# ...
